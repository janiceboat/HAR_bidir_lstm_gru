# %%
# !python --version
# Out:
# Python 3.10.9

# %%
import cv2
import mediapipe as mp
import csv

# %%
def write_landmarks_to_csv(landmarks, frame_number, csv_data):
    #print(f"Landmark coordinates for frame {frame_number}:")
    for idx, landmark in enumerate(landmarks):
        #print(f"{mp_pose.PoseLandmark(idx).name}: (x: {landmark.x}, y: {landmark.y}, z: {landmark.z})")
        csv_data.append([video_name,frame_number, mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y, landmark.z])
    #print("\n")

# %%
import os
#path = "J://COMProfile//Downloads//test//"
#path = "J://COMProfile//Downloads//video//"
path = "C:\\Users\\janic\\Downloads\\train_video\\"

dir_list = os.listdir(path)
print(path)
print(dir_list)
# Out:
# C:\Users\janic\Downloads\train_video\
# ['jumping01.mp4', 'jumping02.mp4']

# %%
# Initialize MediaPipe Pose and Drawing utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose()

# %%
import datetime

csv_data = []
output_csv = 'C:\\Users\\janic\\Downloads\\output_data.csv'

for name in dir_list:
    video_path = path + name
    video_name = name.replace('.mp4','')
    print(video_path)
    print('Video start time:', datetime.datetime.now())

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    frame_number = 0


    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert the frame to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the frame with MediaPipe Pose
        result = pose.process(frame_rgb)

        # Draw the pose landmarks on the frame
        if result.pose_landmarks:
            mp_drawing.draw_landmarks(frame, result.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            # Add the landmark coordinates to the list and print them
            write_landmarks_to_csv(result.pose_landmarks.landmark, frame_number, csv_data)

        # Display the frame
        #cv2.imshow('MediaPipe Pose', frame)

        # Exit if 'q' key is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        frame_number += 1

    cap.release()
    cv2.destroyAllWindows()
    print('Video end time:', datetime.datetime.now())
    
with open(output_csv, 'w', newline='') as csvfile:        
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(['video_name','frame_number', 'landmark', 'x', 'y', 'z'])
    csv_writer.writerows(csv_data)
    #print(csv_data)
# Out:
# C:\Users\janic\Downloads\train_video\jumping01.mp4
# Video start time: 2024-06-02 18:35:22.757108
# C:\Users\janic\anaconda3\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Video end time: 2024-06-02 18:35:46.348057
# C:\Users\janic\Downloads\train_video\jumping02.mp4
# Video start time: 2024-06-02 18:35:46.349058
# Video end time: 2024-06-02 18:36:12.330276
# ...

# %%
want_landmark = ['LEFT_HIP','RIGHT_HIP'
                ,'LEFT_KNEE','RIGHT_KNEE'
                ,'LEFT_SHOULDER','RIGHT_SHOULDER'
                ,'LEFT_ELBOW','RIGHT_ELBOW'
                ,'LEFT_WRIST','RIGHT_WRIST']

want_landmark
# Out:
# ['LEFT_HIP',
#  'RIGHT_HIP',
#  'LEFT_KNEE',
#  'RIGHT_KNEE',
#  'LEFT_SHOULDER',
#  'RIGHT_SHOULDER',
#  'LEFT_ELBOW',
#  'RIGHT_ELBOW',
#  'LEFT_WRIST',
#  'RIGHT_WRIST']

# %%
#csv_data

new_list = []

for x in csv_data:
    if 'LEFT_HIP' in x:
        new_list.append(x)
    if 'RIGHT_HIP' in x:
        new_list.append(x)
        
    if 'LEFT_KNEE' in x:
        new_list.append(x)
    if 'RIGHT_KNEE' in x:
        new_list.append(x)
        
    if 'LEFT_SHOULDER' in x:
        new_list.append(x)
    if 'RIGHT_SHOULDER' in x:
        new_list.append(x)
        
    if 'LEFT_ELBOW' in x:
        new_list.append(x)
    if 'RIGHT_ELBOW' in x:
        new_list.append(x)
        
    if 'LEFT_WRIST' in x:
        new_list.append(x)
    if 'RIGHT_WRIST' in x:
        new_list.append(x)
        

#print(new_list)

# %%
#output_csv = 'output_data2_test'

output_csv = 'C:\\Users\\janic\\Downloads\\output_data2_train.txt'

# Save the CSV data to a file
with open(output_csv, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(['video_name','frame_number', 'landmark', 'x', 'y', 'z'])
    csv_writer.writerows(new_list)
